# %%
# replicate readme
import whisper

# %%
model = whisper.load_model(name="medium", device='cuda:0',download_root = 'pretrained_models/whisper-medium/')
result = model.transcribe("audio.mp3")
print(result["text"])
